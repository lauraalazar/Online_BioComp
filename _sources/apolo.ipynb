# %% [markdown]
# # Instalación y Requisitos
# - Global Protect VPN
#     - primera vez: introduce url
#     - llenar credenciales (user + password x2)
#     - cambio de contraseña
# - leto.omega.edu.co

# %% [markdown]
# # Acceso a
# - Putty ()
# - Terminal (ssh)
# - Visual Studio Code

# %% [markdown]
# # Comandos Básicos

# %%
ssinfo

# %% [markdown]
# ## Nodos
# - allocated
# - mixed
# - idle
# - drained
#
# ## Cpus

# %%
ssqueue

# %% [markdown]
# ## Trabajos en fila

# %% [markdown]
# ## Módulos

# %%
module avail
module load python
module unload

# %% [markdown]
# # Enviar trabajo
# Para generar una plantilla automática

# %%
create_slurm

# %% [markdown]
# ### Sintaxis de slurm

# %%
sbatch

# %% [markdown]
# # Copiar archivos entre PC
# - winscp
# - scp

# %% [markdown]
# # Ver trabajos personales

# %%
my_jobs

# %% [markdown]
# ## Entrar a un nodo específico
# revisar si utiliza mucho swap (memoria tempora)

# %% [markdown]
# ssh compute-0-29
# stop
# quit

# %% [markdown]
# ### Para cancelar

# %%
my_jobs
1-3
